# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn.datasets import make_blobs

# %% [markdown]
# # Dataset preperation

# %%
x,y = make_blobs?

# %%
x,y = make_blobs

# %%
x,y = make_blobs(n_samples=500,n_features=2 ,centers=5,random_state=3)

# %%
plt.figure(0)
plt.grid(True)
plt.scatter(x[:, 0] , x[:,1],c=y)
plt.show()

# %%
k = 5 
color = ["green","red","blue","yellow","orange"]

clusters={}


for i  in range(k):
    center = 10*(2*np.random.random((x.shape[1],))-1)
    
    points=[]
    cluster = {
        'center':center,
        'points':points,
        'color':color[i]
    }
    
    clusters[i] = cluster

# %%
clusters
# Out:
# {0: {'center': array([ 2.46968054, -2.88353263]),
#   'color': 'green',
#   'points': []},
#  1: {'center': array([5.08198394, 5.48084856]), 'color': 'red', 'points': []},
#  2: {'center': array([8.44213566, 5.06332747]), 'color': 'blue', 'points': []},
#  3: {'center': array([-2.99033064, -3.69258931]),
#   'color': 'yellow',
#   'points': []},
#  4: {'center': array([-2.72859999,  7.13939247]),
#   'color': 'orange',
#   'points': []}}

# %%
def distance(v1,v2):
    return np.sqrt(np.sum((v1-v2)**2))

# %%
v1= np.array([1,2])
v2 = np.array([4,6])
print(distance(v1,v2))
# Out:
# 5.0

# %%
#Assign every point to one of the cluster
def assignPointToClusters(clusters): #E-step
    for ix in range(x.shape[0]):
        dist=[]
        curr_x = x[ix]

        for kx in range(k):
            d = distance(curr_x,clusters[kx]['center'])
            dist.append(d)

        current_cluster = np.argmin(dist)

        clusters[current_cluster]['points'].append(curr_x)
        
        


def updateClusters(clusters): # M- step ->we update every cluster center according to mean
    
    for kx in range(k):
        
        pts = np.array(clusters[kx]['points'])
        
        if pts.shape[0] > 0:
            new_u = pts.mean(axis=0)
            clusters[kx]['center']=new_u
            clusters[kx]['points']=[] # Clear the list
        


def plotClusters(clusters):
    
    for kx in range(k):
        
        pts = np.array(clusters[kx]['points'])
        print(pts.shape)
        
        # Plot the points
        
        try:
            
            plt.scatter(pts[:,0],pts[:,1],color=clusters[kx]['color'])
            
        except:
            pass
        
        
        #Plot the cluster centers
        
        uk = clusters[kx]['center']
        plt.scatter(uk[0],uk[1],color="black",marker='*')

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
# Out:
# (4, 2)
# (160, 2)
# (144, 2)
# (576, 2)
# (116, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (6, 2)
# (240, 2)
# (216, 2)
# (864, 2)
# (174, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (40, 2)
# (26, 2)
# (100, 2)
# (262, 2)
# (72, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (66, 2)
# (57, 2)
# (100, 2)
# (235, 2)
# (42, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (94, 2)
# (68, 2)
# (100, 2)
# (205, 2)
# (33, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (101, 2)
# (58, 2)
# (100, 2)
# (198, 2)
# (43, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (103, 2)
# (53, 2)
# (100, 2)
# (196, 2)
# (48, 2)

# %%
assignPointToClusters(clusters)
plotClusters(clusters)
updateClusters(clusters)
# Out:
# (104, 2)
# (49, 2)
# (100, 2)
# (195, 2)
# (52, 2)
